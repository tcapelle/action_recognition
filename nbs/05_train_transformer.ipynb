# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Transformer
# > Training a basic transformer model over image sequences.

# %%
from fastai2.vision.all import *
from action_recognition.core import *
from action_recognition.models import *

# %%
torch.cuda.set_device(0)
torch.cuda.get_device_name()
# Out:
# 'Quadro RTX 8000'

# %%
PATH = Path.cwd().parent/'data'
Path.BASE_PATH = PATH

IMAGE_PATH = PATH/'UCF-101-frames'
SPLIT_PATH = PATH/'ucfTrainTestlist'

# %%
files = get_sequence_paths(IMAGE_PATH)

# %%
seq_len = 20
image_size = 128
bs = 1  #only supports 1

# %% [markdown]
# you could put this split on a text file:

# %%
#slow
val_idxs = get_split_idxs()

# %%
dls = get_action_dataloaders(files, bs=bs, image_size=image_size, seq_len=seq_len, val_idxs=val_idxs, random_sample=False)

# %%
dls.show_batch()

# %% [markdown]
# ## DETR

# %%
model = DETR(n_classes=dls.c, hidden_dim=256)

# %%
learn = Learner(dls, model, metrics=[accuracy], wd=0.1, splitter=detr_split).to_fp16()
learn.freeze()

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=2.2908675418875645e-07, lr_steep=1.3182567499825382e-06)

# %%
learn.fit_one_cycle(10, 1e-4)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       30.00% [3/10 38:43<1:30:20]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.663083</td>
#       <td>4.691188</td>
#       <td>0.010309</td>
#       <td>12:50</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.693986</td>
#       <td>4.672275</td>
#       <td>0.011367</td>
#       <td>12:58</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.659535</td>
#       <td>4.646760</td>
#       <td>0.009252</td>
#       <td>12:54</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='7648' class='' max='9537', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       80.19% [7648/9537 09:13<02:16 4.6724]
#     </div>

# %%
learn.show_results()

# %% [markdown]
# ## Train with attention
# > We will predict with an attention layer over the full output sequence from the LSTM layer.

# %%
model2 = ConvLSTM(num_classes=dls.c, hidden_dim=256, lstm_layers=2, bidirectional=True, attention=True)

# %%
learn2 = Learner(dls, model2, metrics=[accuracy], wd=0.1, cbs=[ModelResetter()], splitter=convlstm_splitter).to_fp16()
learn2.freeze()

# %%
learn2.lr_find()
# Out:
# SuggestedLRs(lr_min=0.002290867641568184, lr_steep=0.005248074419796467)

# %%
learn2.fit_one_cycle(10, 5e-3)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/10 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='263' class='' max='298', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       88.26% [263/298 00:47<00:06 2.0170]
#     </div>

# %%
learn2.show_results()
